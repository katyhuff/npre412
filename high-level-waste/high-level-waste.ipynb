# %% [markdown]
# # High-Level Waste
#
# In the United States, high-level readioactive waste is categorized as such not by its constituent material, but by the history of that material.
#
# ## Learning Objectives
#
# At the end of this lesson, you will be equipped to:
#
# - Describe the characteristics of high level radioactive waste
# - Distinguish among current waste classification schemes domestically and internationally
# - Suggest potential alternative waste classification schemes
# -

# %% [markdown]
# ## Wrap-up
#
# -
# -
# -
# -

# %% [markdown]
# ## References
#
# This section was developed to complement pages YY-ZZ of [1].
#
# [1] N. Tsoulfanidis, The Nuclear Fuel Cycle. La Grange Park, Illinois, USA: American Nuclear Society, 2013.
